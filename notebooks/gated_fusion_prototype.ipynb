# %% [markdown]
# # Gated Fusion Prototype
# This notebook runs a quick verification and small prototype run (CPU-friendly) using a small subset of the AZH dataset.

# %%
# Quick check imports
import torch # type: ignore
print('torch:', torch.__version__)
